# %% [markdown]
# # $11^{th}$ excercise - 11.3: Multidimensional fit
# ## Notebook setup
# #### Used libraries

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

# %% [markdown]
# #### Functions

# %%
def PlotSetup():
    plt.axes().set_facecolor(bg1)
    plt.grid(alpha=0.3)

def MultiplotSetup(fig,r,c,nplots=0):
    if nplots == 0 : nplots=r*c
    for i in range(nplots):
        plt.subplot(r,c,i+1)
        fig.axes[i].set_facecolor(bg1)
        plt.grid(alpha=0.3) 

def Legend():
    leg = plt.legend(facecolor=bg2)
    for text in leg.get_texts():
        text.set_color(el1)

# %%
def create_model(neurons_per_layer,act_function):
    model = tf.keras.Sequential()
    model.add(Dense(neurons_per_layer[0], input_shape=(2,), activation=act_function))
    for neurons in neurons_per_layer[1:]:
        model.add(Dense(neurons, activation=act_function))
    model.add(Dense(1,))

    return model

def compile_model(neurons_per_layer,act_function,loss_function,opt_function):
    np.random.seed(0)
    tf.random.set_seed(0)
    # create the model
    model=create_model(neurons_per_layer,act_function)
    # compile the model
    model.compile(loss=loss_function,
                  optimizer=opt_function)

    return model

def test_model(model):
    score = model.evaluate(x_train, y_train, batch_size=32, verbose=0)  
    print("Loss: training data ->", score)
    
    score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=0)  
    print("Loss: validation data -> ", score)
    
    score = model.evaluate(x_target, y_target, batch_size=32, verbose=0)  
    print("Loss: exact function -> ", score)

# %%
npoints=200
def show_results(model, history):
    plt.figure(figsize=(8,8))
    PlotSetup()
    plt.title("Model loss")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    
    plt.plot(history.history["loss"], label="Training", c=el1)
    plt.plot(history.history["val_loss"], label="Validation", c=el2)
    
    Legend()
    
    plt.show()

    
    fig=plt.figure(figsize=(16,24))
    MultiplotSetup(fig,3,2)
    fig.suptitle("Section of 3D plot")
    fixs=[-1,0,1]
    coord_fixed=['x','y']

    for i in range(6):
        plt.subplot(3,2,(i+1))
        fix=fixs[i//2]
        ifix=i%2
        plt.title("Section at "+coord_fixed[ifix]+" = "+str(fix))
        plt.xlabel(coord_fixed[1-ifix])
        plt.ylabel("z")
        xt = np.random.uniform(-1.5, 1.5, npoints) # [xx...x]
        yt = np.ones(npoints)*fix                  # [yy...xy]
        
        x_predict = np.vstack((xt,yt))             # [[xx...x]
                                                   #  [yy...y]]
            
        if(ifix): x_predict=x_predict[::-1]        # swap if y is fixed
            
        x_predict = np.transpose(x_predict)        # [[xy]
                                                   #  [xy] 
                                                   #  ....
                                                   #  [xy]] 
            
        y_predict = model.predict(x_predict)
        
        plt.scatter(x_predict[:,ifix], y_predict, label='Predicted', c=el1)
        plt.scatter(xt, f(x_predict), label='Target',c=el3)   
        Legend()

# %% [markdown]
# #### Colors

# %%
#background
bg1 = "#191724" 
bg2 = "#26233a" 
#elements
el1 = "#e0def4" 
el2 = "#f6c177" 
el3 = "#eb6f92" 
#errorbars
er1 = "#908caa"  
er2 = "#6e6a86"

# %% [markdown]
# ## The excercise
# There exists a concrete way to visualize the fact that NN are universal fitters for two-input functions too. Starting from the fact that two neurons in a single hidden layer are able to reproduce a bin in the plane we can extend the reasoning to three dimension: a bin in the plane becomes a stripe in 3D, so creating two bins, one for the x-coordinate and the other for the y-coordinate, produces two ortogonal tripes in the space with a bump in the area of intersection. By adding a second layer with a sigle neuron that activates only when a certain treshold is exceeded, we can preserve only the bump, that is a 3D bin. Following the same procedure we can produce an arbitrary number of bins to approximate the function.
#
# Here we want to fit
# \begin{equation}
# f(x,y) = \sin(x^2+y^2)
# \end{equation}

# %%
def f(x):
    x2=x[:,1]
    x1=x[:,0]
    return np.sin(x1**2+x2**2)

# %% [markdown]
# We fix the parameters for the training

# %%
ntrain=20000
batch_size=32
epochs=60

# %% [markdown]
# And produce the datasets

# %%
np.random.seed(0)
sigma=0.5


x_train = np.random.uniform(-1.5, 1.5, (ntrain,2))
y_train = np.random.normal(f(x_train), sigma) 

x_valid = np.random.uniform(-1.5, 1.5,(ntrain // 10,2))
y_valid = np.random.normal(f(x_valid), sigma)

x_target = x_valid
y_target = f(x_target)

# %% [markdown]
# We did some unsuccesfull attempts (not shown here) to fit the function. We found out that by increasing the number of layers the fit got better. The difference was bigger than that due to a change in the number of neurons: this fact seems to suggest that for multidimensional functions increasing the number of layers has a greater impact on the performances of the model (in fact, even a two-layers model worked quite poorely) than increasing the number of neurons. Noticing that the error was still decreasing, we increased the number of epochs from 30 (previous excercise) to 60.

# %%
model=compile_model([25,25,25],'tanh','mse','sgd')
history = model.fit(x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        verbose=1,
        shuffle=True,
        validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/60
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4062 - val_loss: 0.3860
# Epoch 2/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4005 - val_loss: 0.3866
# Epoch 3/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3993 - val_loss: 0.3839
# Epoch 4/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3983 - val_loss: 0.3836
# Epoch 5/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3957 - val_loss: 0.3800
# Epoch 6/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3919 - val_loss: 0.3750
# Epoch 7/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3856 - val_loss: 0.3684
# Epoch 8/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3779 - val_loss: 0.3591
# Epoch 9/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3702 - val_loss: 0.3552
# Epoch 10/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3662 - val_loss: 0.3528
# Epoch 11/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3626 - val_loss: 0.3462
# Epoch 12/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3601 - val_loss: 0.3458
# Epoch 13/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3585 - val_loss: 0.3430
# Epoch 14/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3561 - val_loss: 0.3410
# Epoch 15/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3538 - val_loss: 0.3378
# Epoch 16/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3507 - val_loss: 0.3364
# Epoch 17/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3472 - val_loss: 0.3334
# Epoch 18/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3427 - val_loss: 0.3262
# Epoch 19/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3348 - val_loss: 0.3262
# Epoch 20/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3272 - val_loss: 0.3128
# Epoch 21/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3184 - val_loss: 0.3087
# Epoch 22/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3129 - val_loss: 0.3006
# Epoch 23/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3082 - val_loss: 0.2986
# Epoch 24/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3038 - val_loss: 0.2942
# Epoch 25/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.3001 - val_loss: 0.2913
# Epoch 26/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2966 - val_loss: 0.2949
# Epoch 27/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2926 - val_loss: 0.2813
# Epoch 28/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2882 - val_loss: 0.2778
# Epoch 29/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2848 - val_loss: 0.2740
# Epoch 30/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2806 - val_loss: 0.2744
# Epoch 31/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2772 - val_loss: 0.2704
# Epoch 32/60
# 625/625 [==============================] - 2s 3ms/step - loss: 0.2734 - val_loss: 0.2683
# Epoch 33/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2706 - val_loss: 0.2747
# Epoch 34/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2685 - val_loss: 0.2671
# Epoch 35/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2668 - val_loss: 0.2628
# Epoch 36/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2653 - val_loss: 0.2610
# Epoch 37/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2634 - val_loss: 0.2628
# Epoch 38/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2627 - val_loss: 0.2619
# Epoch 39/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2616 - val_loss: 0.2661
# Epoch 40/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2608 - val_loss: 0.2607
# Epoch 41/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2603 - val_loss: 0.2610
# Epoch 42/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2601 - val_loss: 0.2644
# Epoch 43/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2588 - val_loss: 0.2598
# Epoch 44/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2594 - val_loss: 0.2591
# Epoch 45/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2585 - val_loss: 0.2590
# Epoch 46/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2585 - val_loss: 0.2625
# Epoch 47/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2584 - val_loss: 0.2574
# Epoch 48/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2582 - val_loss: 0.2562
# Epoch 49/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2578 - val_loss: 0.2552
# Epoch 50/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2572 - val_loss: 0.2575
# Epoch 51/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2574 - val_loss: 0.2563
# Epoch 52/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2575 - val_loss: 0.2604
# Epoch 53/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2568 - val_loss: 0.2584
# Epoch 54/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2571 - val_loss: 0.2600
# Epoch 55/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2566 - val_loss: 0.2544
# Epoch 56/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2568 - val_loss: 0.2571
# Epoch 57/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2567 - val_loss: 0.2574
# Epoch 58/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2566 - val_loss: 0.2572
# Epoch 59/60
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2561 - val_loss: 0.2561
# Epoch 60/60
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2565 - val_loss: 0.2584

# %%
test_model(model)
show_results(model,history)
# Out:
# Loss: training data -> 0.2548930048942566
# Loss: validation data ->  0.2584204077720642
# Loss: exact function ->  0.005392266903072596
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 4ms/step
# 7/7 [==============================] - 0s 6ms/step
# 7/7 [==============================] - 0s 5ms/step
# 7/7 [==============================] - 0s 6ms/step
